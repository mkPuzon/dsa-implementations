# %%
# stop Jupyter from using cached imports durring development
# %load_ext autoreload
# %autoreload 2


import os
import sys
# add path for implementation code
pr = os.path.abspath(os.path.join(".."))
if pr not in sys.path:
    sys.path.append(pr)

# %% [markdown]
# # Data Structures

# %% [markdown]
# ## Stack

# %%
from implementations.stack import Stack

def test_stack() -> None:
    s = Stack()
    
    # test behavior when empty
    print(f"Peeked: {s.peek()}")
    print(f"Popped: {s.pop()}")
    print(s)
    assert s.is_empty() == True
    
    # test adding items
    s.add(1)
    s.add(2)
    s.add(3)
    assert s.num_items == 3
    print("Added items")
    print(s)
    print(f"Popped: {s.pop()}")
    print(f"Peeked: {s.peek()}")
    print(s)
    assert s.num_items == 2
    
test_stack()
# Out:
# Peeked: None
# Popped: None
# Stack contains 0 items. From bottom to top:
# []
# Added items
# Stack contains 3 items. From bottom to top:
# [1, 2, 3]
# Popped: 3
# Peeked: 2
# Stack contains 2 items. From bottom to top:
# [1, 2]

# %% [markdown]
# Expected Output:
# ```Peeked: None
# Popped: None
# Stack contains 0 items. From bottom to top:
# []
# Added items
# Stack contains 3 items. From bottom to top:
# [1, 2, 3]
# Popped: 3
# Peeked: 2
# Stack contains 3 items. From bottom to top:
# [1, 2]
# ```

# %% [markdown]
# ## Queue

# %%
from implementations.queue import Queue

def test_queue():
    pass

# %% [markdown]
# # Algorithms
